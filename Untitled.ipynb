# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('data/attacks.csv', encoding='latin1')

# %%
data.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
data.shape
# Out:
# (25723, 24)

# %%
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
data.Date.fillna('unknown', inplace=True) # relleno los nulo de esta lista

# %%
data=data.rename(columns={'Case Number': 'Case_Number'}) #renombro las columnas para quitar los espacios

# %%
data=data.rename(columns={'Sex ': 'Sex1'}) #renombro las columnas para quitar los espacios

# %%
data.Sex1.fillna('unknown', inplace=True)

# %%
data=data.dropna(how='all')  #eliminacion de filas nulas

# %%
data = data.loc[df.isnull().mean(axis=1) <= 0.5] # elimino las filas que contengan más de un % de valores nulos. Demasiados nulos

# %%
columns=data.isna().sum() #suma de todos los valores nulos por columna
columns
# Out:
# Case_Number               17021
# Date                          0
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
data.describe(include='all').T #vamos a intentar buscar si hubiera algún duplicado

# %%
data = data.drop_duplicates()

# %%
plt.figure(figsize=10, 6))       #dibujamos un grafico para ver los valores nulos

sns.heatmap(data.isna(),
           yticklabels=False,
           cmap= 'viridis',
           cbar=False)

plt.show();
# Out:
#   File "C:\Users\jelsa\AppData\Local\Temp\ipykernel_9532\890579994.py", line 1
#     plt.figure(figsize=10, 6))
#                             ^
# SyntaxError: positional argument follows keyword argument

# %%
data.shape
# Out:
# (6312, 24)

# %%
data.head(20)
# Out:
#      Case_Number                  Date    Year          Type       Country  \
# 0     2018.06.25           25-Jun-2018  2018.0       Boating           USA
# 1     2018.06.18           18-Jun-2018  2018.0    Unprovoked           USA
# 2     2018.06.09           09-Jun-2018  2018.0       Invalid           USA
# 3     2018.06.08           08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4     2018.06.04           04-Jun-2018  2018.0      Provoked        MEXICO
# 5   2018.06.03.b           03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 6   2018.06.03.a           03-Jun-2018  2018.0    Unprovoked        BRAZIL
# 7     2018.05.27           27-May-2018  2018.0    Unprovoked           USA
# 8   2018.05.26.b           26-May-2018  2018.0    Unprovoked           USA
# 9   2018.05.26.a           26-May-2018  2018.0    Unprovoked           USA
# 10    2018.05.24           24-May-2018  2018.0      Provoked     AUSTRALIA
# ...

# %%
data.Year
# Out:
# 0        2018.0
# 1        2018.0
# 2        2018.0
# 3        2018.0
# 4        2018.0
#           ...
# 6307        NaN
# 6308        NaN
# 6309        NaN
# 8702        NaN
# 25722       NaN
# Name: Year, Length: 6312, dtype: float64

# %%
data.Year.value_counts()
# Out:
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
#          ...
# 1786.0      1
# 1785.0      1
# 1784.0      1
# 1783.0      1
# 1815.0      1
# Name: Year, Length: 249, dtype: int64

# %%
data.Year.isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 6307      True
# 6308      True
# 6309      True
# 8702      True
# 25722     True
# Name: Year, Length: 6312, dtype: bool

# %%
data=data.iloc[:-122]  # para quitar las filas que no me interesan que son las que aparecen en 0 y tienen relacion con la columna de los dates de antes de cristo.

# %%
data.shape
# Out:
# (6190, 24)

# %%
data.iloc[:6400]
# Out:
#      Case_Number         Date    Year        Type           Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating               USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked               USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid               USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked         AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked            MEXICO
# ...          ...          ...     ...         ...               ...
# 6185     ND-0150  Before 1934     0.0  Unprovoked           URUGUAY
# 6186     ND-0149  Before 1934     0.0  Unprovoked           URUGUAY
# 6187     ND-0148        2009?     0.0  Unprovoked               USA
# 6188     ND-1940  Before 1930     0.0  Unprovoked  PAPUA NEW GUINEA
# 6189     ND-0139    1880-1899     0.0  Unprovoked         AUSTRALIA
#
#                  Area                        Location           Activity  \
# 0          California     Oceanside, San Diego County           Paddling
# ...

# %%
data.Year.fillna('0', inplace=True)

# %%
data.['Year'] = pd.to_numeric(data['Year'], errors='coerce') # para poder cambiar los valores no numericos a numericos para que después pueda pasar a integer el valor de 2018
# Out:
#   File "C:\Users\jelsa\AppData\Local\Temp\ipykernel_14448\2096291577.py", line 1
#     data.['Year'] = pd.to_numeric(data['Year'], errors='coerce') # para poder cambiar los valores no numericos a numericos para que después pueda pasar a integer el valor de 2018
#          ^
# SyntaxError: invalid syntax

# %%
data['Year'] = data['Year'].astype(int) #intentando convertir los floats en integers para que el año sea 2018

# %%
data.data.loc[data['Year']==0] # para que me dé los valores en 0 y después poderlo elimnarlo

# %%
data.data[data['Year'] =0]  #para eliminar las filas que contienen 0s

# %%
data.Type.isna()

# %%
data.Type.value_counts()  # La veo correcta no voy ha hacer ninguna modificación
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9532\2357121212.py in <module>
# ----> 1 data.Type.value_counts()  # La veo correcta no voy ha hacer ninguna modificación
#
# NameError: name 'data' is not defined

# %%
data.Country.unique()

# %%
data.Country.value_counts

# %%
data.Country.isna()

# %%
data.Country.fillna('unknown', inplace=True)

# %%
data.Country = data.Country.str.replace(r"(.*)UNITED ARAB EMIRATES(.*)", 'UNITED ARAB EMIRATES')
data.Country = data.Country.str.replace(r"(.*)Fiji(.*)" , 'FIJI')
data.Country = data.Country.str.replace(r"(.*)British(.*)" , 'UK')
data.Country = data.Country.str.replace(r"(.*)BRITISH(.*)" , 'UK')
data.Country = data.Country.str.replace(r"(.*)BRITAIN(.*)" , 'UK')
data.Country = data.Country.str.replace(r"(.*)DIEGO GARCIA(.*)" , 'Unknown')
data.Country = data.Country.str.replace(r"(.*)OCEAN(.*)" , 'Unknown')
data.Country = data.Country.str.replace(r"(.*)SEA(.*)" , 'Unknown')
data.Country = data.Country.str.replace(r"(.*)Between(.*)" , 'Unknown')
data.Country = data.Country.str.replace(r"(.*)SRI LANKA(.*)" , 'SRI LANKA')
data.Country = data.Country.str.replace(r"(.*)MEXICO(.*)" , 'MEXICO')
data.Country = data.Country.str.replace(r"(.*)Sierra Leone(.*)" , 'SIERRA LEONE')
data.Country = data.Country.str.replace(r"(.*)Seychelles(.*)" , 'SEYCHELLES')     # para cambiar el nombre del país que no están muy correctos

# %%
data.Area.fillna('unknown', inplace=True)

# %%
data.Area

# %%
data.value_counts

# %%
data.Area.unique()

# %%
data.head()

# %%
data.pivot_table(index=['Country'], columns=['Type']) me he equivocado quería poner activity # quiero hacer una pivot table con las columnas indicadas para ver la relación entre el país y el Activity.

# %%
 data=data.iloc[:-212] # una vez veo que la información no es relevante procedo a eliminarlo.

# %%
data.shape

# %%
data.head()

# %%
columns=data.isna().sum() #compruebo a ver cuantos valores nulos me siguen quedando por columna
columns

# %%
data['Name']=data['First_Name'].str.join('-')+data['Last_Name']  #he querido unir los nombre pero se me ha ido de las manos
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'First_Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data = data('Name', sep='-') # otro intento para poder unir los nombres de la columna
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14448\1239374218.py in <module>
# ----> 1 data = data('Name', sep='-')
#
# TypeError: 'DataFrame' object is not callable

# %%
data.head()

# %%
data.dropna(subset=['Name'] , inplace=True) #he querido quitar los valores nulos de la columna

# %%
data.shape # por lo que se ve no había

# %%
data.Name.value_counts

# %%
data.Name.fillna('unknown', inplace=True)

# %%
data.Sex1.fillna('unknown', inplace=True)

# %%
data.Age.fillna('0', inplace=True) # a Age donde pone NAN le voy a meter un 0 para que luego pueda hacer la media y por tanto necesito que todos los elemnetos sean integers

# %%
data['Age'] = data['Age'].str.replace('\D', '') # después lo que le hago es buscar quitar a la fila 48 40s esa s para después pasar todos los valores y pasarlos a numérico y sacar la media

# %%
data['Age']= pd.to_numeric(data['Age']) # paso to los valores a numerico para poder hacer la media

# %%
data['Age'] = data['Age'].astype(int) # pasar todos los numeros a integer por si hubiera algún float

# %%
data =data['Age'].mean() #hago la media

# %%
data = data[data['Age'] <=mean] # quiero que solo me queden las personas de menor edad que la media es decir, las más propensas a sufrir ataques ya que hacen más actividades acuaticas y por tanto en un principio las que más ataques van a sufrir.

# %%
data=data.rename(columns={'Fatal (Y/N)': 'Fatal(Y/N)'}) # renombro la columna de Fatal para que no me dé problemas después

# %%
Non_Fatal(Y/N)=[]

for X in Fatal(Y/N):
    if x!=0
    Non_Fatal(Y/N).append(x)

Non_Fatal(Y/N)=data[data['Fatal(Y/N)'].apply(lambda x:  x!=0)  # me quiero quedar con las operaciones que no son fatales y el resto de lineas ser eliminado.

# %%
data=data.rename(columns={'Species ': 'Species'}) #renombro species para quitarle el espacio

# %%
data.Species.fillna('unknown', inplace=True)

# %%
data.['Species']= data['Species'].apply(lambda x: str(x) + 'm') #quiero añadir en cada string la palabra 'metros' para indicar la longitud de cada Tiburón

# %%
data.replace(to_replace=('''), value='m', inplace=True) # quitar las ' de algunos de las medidas de los tiburones y sustituirlas por m

# %%
data = (data['Species']>= 2] & (data['Species']=< 7] # un vez habiendo señalado los metros de los tiburones quiero que me filtre los que son entre 2 y 7 metros ya que son los más comunes y por tanto los que más ataques realizarán

# %%
Objetivo es bucar la correlación entre las especies de tiburón y lo tipos de ataques que generan
